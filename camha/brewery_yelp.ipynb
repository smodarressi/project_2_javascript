# %%
import requests
import pandas as pd
import json
from pprint import pprint
import api_keys
import time

# %%
brewery_csv = pd.read_csv('ca_breweries_filtered.csv', engine='python',sep='\t')
brewery_csv.to_csv('brewery_yelp.csv', encoding='utf-8')

brewery_csv.head()
# Out:
#    Unnamed: 0                  brewery names business type            address  \
# 0         0.0  10 Barrel Brewing - San Diego     Breweries          1501 E St
# 1         1.0      101 North Brewing Company     Breweries      1304 Scott St
# 2         2.0       13 Point Brewing Company     Breweries      8035 Broadway
# 3         3.0                     14 Cannons     Breweries  31125 Via Colinas
# 4         4.0       Latchkey Brewing Company     Breweries    1795 Hancock St
#
#                   city      zip        lat        long  yelp rating  \
# 0            San Diego  92101.0  32.714559 -117.150229          4.5
# 1  Petaluma California  94954.0  38.269950 -122.664930          4.0
# 2          Lemon Grove  91945.0  32.742786 -117.024910          4.5
# 3     Westlake Village  91362.0  34.153554 -118.803169          4.5
# 4            San Diego  92110.0  32.742469 -117.184668          5.0
#
#    number of yelp reviews
# 0                   364.0
# 1                    64.0
# ...
