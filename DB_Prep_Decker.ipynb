# %%
import os

import pandas as pd
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import inspect
from sqlalchemy import MetaData
from sqlalchemy import Table

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

# %%
db_uri = "sqlite:///static/data/brewerywinery.db"
engine = create_engine(db_uri)

# %%
# # # reflect an existing database into a new model
Base = automap_base()
# # # reflect the tables
Base.prepare(engine, reflect=True)

Base.classes.keys()
# Out:
# ['brewery_winery_yelp']

# %%
brew_wine = Base.classes.brewery_winery_yelp
session = Session(engine)
inspector = inspect(engine)

columns = inspector.get_columns('brewery_winery_yelp')

# %%
column_ls = []

for c in columns:
    column_ls.append(c['name'])
    print(c['name'], c['type'])
# Out:
# ID INTEGER
# names TEXT
# address TEXT
# businesstype TEXT
# city TEXT
# zip INTEGER
# lat REAL
# long REAL
# numberofyelpreviews INTEGER
# yelprating INTEGER
# 'ID'

# %%
column_ls
# Out:
# ['names',
#  'address',
#  'businesstype',
#  'city',
#  'zip',
#  'lat',
#  'long',
#  'numberofyelpreviews',
#  'yelprating']

# %%
query = session.query(brew_wine.ID,
                        brew_wine.names,
                        brew_wine.address,
                        brew_wine.businesstype,
                        brew_wine.city,
                        brew_wine.zip,
                        brew_wine.lat,
                        brew_wine.long,
                        brew_wine.numberofyelpreviews,
                        brew_wine.yelprating).all()

brew_wine_ls = []

for ID, names, address, businesstype, city, Zip, lat, long, numberofyelpreviews, yelprating in query:
    brew_wine_ls.append({column_ls[0]: ID,
                          column_ls[1]: names
                          column_ls[2]: address,
                          column_ls[3]: businesstype,
                          column_ls[4]: city,
                          column_ls[5]: Zip,
                          column_ls[6]: lat,
                          column_ls[7]: long,
                          column_ls[8]: numberofyelpreviews,
                          column_ls[9]: yelprating
                         })
    
brew_wine_dict
# Out:
# {1: {'names': '10 Barrel Brewing - San Diego',
#   'address': '1501 E St',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92101,
#   'lat': 32.71455905,
#   'long': -117.1502286,
#   'numberofyelpreviews': 364,
#   'yelprating': 4.5},
#  2: {'names': '101 North Brewing Company',
#   'address': '1304 Scott St',
#   'businesstype': 'Breweries',
#   'city': 'Petaluma California',
#   'zip': 94954,
#   'lat': 38.26995,
#   'long': -122.66493,
#   'numberofyelpreviews': 64,
#   'yelprating': 4},
#  3: {'names': '13 Point Brewing Company',
#   'address': '8035 Broadway',
#   'businesstype': 'Breweries',
#   'city': 'Lemon Grove',
#   'zip': 91945,
#   'lat': 32.742786,
#   'long': -117.02491,
#   'numberofyelpreviews': 35,
#   'yelprating': 4.5},
#  4: {'names': '14 Cannons',
#   'address': '31125 Via Colinas',
#   'businesstype': 'Breweries',
#   'city': 'Westlake Village',
#   'zip': 91362,
#   'lat': 34.1535538,
#   'long': -118.8031695,
#   'numberofyelpreviews': 75,
#   'yelprating': 4.5},
#  5: {'names': 'Latchkey Brewing Company',
#   'address': '1795 Hancock St',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92110,
#   'lat': 32.7424694,
#   'long': -117.1846678,
#   'numberofyelpreviews': 24,
#   'yelprating': 5},
#  6: {'names': 'Grass Valley Brewing Company',
#   'address': '141 E Main St',
#   'businesstype': 'Breweries',
#   'city': 'Grass Valley',
#   'zip': 95945,
#   'lat': 39.21931416,
#   'long': -121.0604967,
#   'numberofyelpreviews': 22,
#   'yelprating': 4.5},
#  7: {'names': '21st Amendment Brewery',
#   'address': '2010 Williams St',
#   'businesstype': 'Breweries',
#   'city': 'San Leandro',
#   'zip': 94577,
#   'lat': 37.7120399,
#   'long': -122.1776428,
#   'numberofyelpreviews': 260,
#   'yelprating': 4},
#  8: {'names': '2kids Brewing Co',
#   'address': '8680 Miralani Dr',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92126,
#   'lat': 32.896564,
#   'long': -117.137428,
#   'numberofyelpreviews': 86,
#   'yelprating': 4},
#  9: {'names': '3 Disciples Brewing',
#   'address': '501 Mendocino Ave',
#   'businesstype': 'Breweries',
#   'city': 'Santa Rosa',
#   'zip': 95401,
#   'lat': 38.44193,
#   'long': -122.71558,
#   'numberofyelpreviews': 28,
#   'yelprating': 4.5},
#  10: {'names': '3 Iron Brewing Company',
#   'address': '898 Via Lata',
#   'businesstype': 'Breweries',
#   'city': 'Colton',
#   'zip': 92324,
#   'lat': 34.0559082,
#   'long': -117.3061981,
#   'numberofyelpreviews': 50,
#   'yelprating': 5},
#  11: {'names': '32 North Brewing Co',
#   'address': '8655 Production Ave',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92121,
#   'lat': 32.88274384,
#   'long': -117.1649857,
#   'numberofyelpreviews': 171,
#   'yelprating': 4.5},
#  12: {'names': '47 Hills Brewing Company',
#   'address': '137 S Linden Ave',
#   'businesstype': 'Breweries',
#   'city': 'South San Francisco',
#   'zip': 94080,
#   'lat': 37.644218,
#   'long': -122.413452,
#   'numberofyelpreviews': 159,
#   'yelprating': 4.5},
#  13: {'names': '559 Beer',
#   'address': '356 Pollasky Ave',
#   'businesstype': 'Breweries',
#   'city': 'Clovis',
#   'zip': 93612,
#   'lat': 36.825516,
#   'long': -119.702201,
#   'numberofyelpreviews': 65,
#   'yelprating': 4},
#  14: {'names': '6th & La Brea Brewery & Restaurant',
#   'address': '600 S La Brea Ave',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90036,
#   'lat': 34.06469,
#   'long': -118.34368,
#   'numberofyelpreviews': 266,
#   'yelprating': 4},
#  15: {'names': 'Tap It Brewing',
#   'address': '675 Clarion Ct',
#   'businesstype': 'Breweries',
#   'city': 'San Luis Obispo',
#   'zip': 93401,
#   'lat': 35.24409,
#   'long': -120.64595,
#   'numberofyelpreviews': 100,
#   'yelprating': 4.5},
#  16: {'names': '8one8 Brewing',
#   'address': '8951 De Soto Ave',
#   'businesstype': 'Breweries',
#   'city': 'Canoga Park',
#   'zip': 91304,
#   'lat': 34.2333572,
#   'long': -118.5886849,
#   'numberofyelpreviews': 55,
#   'yelprating': 4.5},
#  17: {'names': '927 Beer Company',
#   'address': '821 Cornwall St',
#   'businesstype': 'Breweries',
#   'city': 'Cambria',
#   'zip': 93428,
#   'lat': 35.56667328,
#   'long': -121.0984573,
#   'numberofyelpreviews': 157,
#   'yelprating': 4.5},
#  18: {'names': 'Abnormal Beer Company',
#   'address': '16990 Via Tazon',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92127,
#   'lat': 33.02385,
#   'long': -117.08575,
#   'numberofyelpreviews': 6,
#   'yelprating': 5},
#  19: {'names': 'Absolution Brewing Company',
#   'address': '2878 Columbia St',
#   'businesstype': 'Breweries',
#   'city': 'Torrance',
#   'zip': 90503,
#   'lat': 33.8431072,
#   'long': -118.3379618,
#   'numberofyelpreviews': 283,
#   'yelprating': 4},
#  20: {'names': 'Stone Brewing - Napa',
#   'address': '920-930 3rd St',
#   'businesstype': 'Breweries',
#   'city': 'Napa',
#   'zip': 94559,
#   'lat': 38.298787,
#   'long': -122.282856,
#   'numberofyelpreviews': 207,
#   'yelprating': 4},
#  21: {'names': 'Aftershock Brewing',
#   'address': '28822 Old Town Front St',
#   'businesstype': 'Breweries',
#   'city': 'Temecula',
#   'zip': 92590,
#   'lat': 33.48840847,
#   'long': -117.1443468,
#   'numberofyelpreviews': 182,
#   'yelprating': 4.5},
#  22: {'names': 'Alameda Island Brewing Company',
#   'address': '1716 Park St',
#   'businesstype': 'Breweries',
#   'city': 'Alameda',
#   'zip': 94501,
#   'lat': 37.7684402,
#   'long': -122.2388611,
#   'numberofyelpreviews': 303,
#   'yelprating': 4.5},
#  23: {'names': 'Alaro Craft Brewery',
#   'address': '2004 Capitol Ave',
#   'businesstype': 'Breweries',
#   'city': 'Sacramento',
#   'zip': 95811,
#   'lat': 38.57312933,
#   'long': -121.481076,
#   'numberofyelpreviews': 157,
#   'yelprating': 4},
#  24: {'names': 'Ale Industries',
#   'address': '3096 E 10th St',
#   'businesstype': 'Breweries',
#   'city': 'Oakland',
#   'zip': 94601,
#   'lat': 37.77619976,
#   'long': -122.2283765,
#   'numberofyelpreviews': 169,
#   'yelprating': 4.5},
#  25: {'names': 'AleSmith Brewing Company',
#   'address': '9990 AleSmith Ct',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92126,
#   'lat': 32.8873241,
#   'long': -117.1493986,
#   'numberofyelpreviews': 410,
#   'yelprating': 4.5},
#  26: {'names': 'Alibi Ale Works - Truckee Public House',
#   'address': '10069 Bridge St',
#   'businesstype': 'Breweries',
#   'city': 'Truckee',
#   'zip': 96161,
#   'lat': 39.3292899,
#   'long': -120.1842621,
#   'numberofyelpreviews': 118,
#   'yelprating': 4.5},
#  27: {'names': 'Align Brewing Company',
#   'address': '8680 Miralani Dr',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92126,
#   'lat': 32.89666,
#   'long': -117.13722,
#   'numberofyelpreviews': 17,
#   'yelprating': 4.5},
#  28: {'names': 'All-American Brew Works',
#   'address': '5120 E La Palma Ave',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92807,
#   'lat': 33.8593551,
#   'long': -117.8062077,
#   'numberofyelpreviews': 95,
#   'yelprating': 4.5},
#  29: {'names': 'Alosta Brewing Co',
#   'address': '692 Arrow Grand Cir',
#   'businesstype': 'Breweries',
#   'city': 'Covina',
#   'zip': 91722,
#   'lat': 34.104594,
#   'long': -117.878892,
#   'numberofyelpreviews': 153,
#   'yelprating': 4.5},
#  30: {'names': '47 Hills Brewing Company',
#   'address': '137 S Linden Ave',
#   'businesstype': 'Breweries',
#   'city': 'South San Francisco',
#   'zip': 94080,
#   'lat': 37.644218,
#   'long': -122.413452,
#   'numberofyelpreviews': 159,
#   'yelprating': 4.5},
#  31: {'names': 'Alpine Beer Company - Tasting Room',
#   'address': '2363 Alpine Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Alpine',
#   'zip': 91901,
#   'lat': 32.835167,
#   'long': -116.762655,
#   'numberofyelpreviews': 492,
#   'yelprating': 4},
#  32: {'names': 'Alta Brewing Co',
#   'address': '1983 Julian Ave',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92113,
#   'lat': 32.70191,
#   'long': -117.14151,
#   'numberofyelpreviews': 27,
#   'yelprating': 4.5},
#  33: {'names': 'Altamont Beer Works',
#   'address': '2402 Research Dr',
#   'businesstype': 'Breweries',
#   'city': 'Livermore',
#   'zip': 94550,
#   'lat': 37.67625,
#   'long': -121.72009,
#   'numberofyelpreviews': 209,
#   'yelprating': 4.5},
#  34: {'names': 'Alvarado Street Brewery',
#   'address': '1315 Dayton St',
#   'businesstype': 'Breweries',
#   'city': 'Salinas',
#   'zip': 93901,
#   'lat': 36.64852496,
#   'long': -121.6308999,
#   'numberofyelpreviews': 58,
#   'yelprating': 4.5},
#  35: {'names': 'Alvarado Street Brewery',
#   'address': '426 Alvarado St',
#   'businesstype': 'Breweries',
#   'city': 'Monterey',
#   'zip': 93940,
#   'lat': 36.59931,
#   'long': -121.89492,
#   'numberofyelpreviews': 1142,
#   'yelprating': 4},
#  36: {'names': 'Amador Brewing Company',
#   'address': '9659 Main St',
#   'businesstype': 'Breweries',
#   'city': 'Plymouth',
#   'zip': 95669,
#   'lat': 38.4819298,
#   'long': -120.8450394,
#   'numberofyelpreviews': 101,
#   'yelprating': 4.5},
#  37: {'names': 'Ambitious Ales',
#   'address': '4019 Atlantic Ave',
#   'businesstype': 'Breweries',
#   'city': 'Long Beach',
#   'zip': 90807,
#   'lat': 33.83122127,
#   'long': -118.1852768,
#   'numberofyelpreviews': 71,
#   'yelprating': 5},
#  38: {'names': 'Amplified Ale Works',
#   'address': '4150 Mission Blvd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92109,
#   'lat': 32.79114172,
#   'long': -117.254326,
#   'numberofyelpreviews': 861,
#   'yelprating': 4},
#  39: {'names': 'Pure Project',
#   'address': '9030 Kenamar Dr',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92121,
#   'lat': 32.8873375,
#   'long': -117.1555986,
#   'numberofyelpreviews': 630,
#   'yelprating': 4.5},
#  40: {'names': 'Anaheim Brewery',
#   'address': '336 S Anaheim Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92805,
#   'lat': 33.83262,
#   'long': -117.9125,
#   'numberofyelpreviews': 299,
#   'yelprating': 4},
#  41: {'names': 'Anchor Brewing Company',
#   'address': '1705 Mariposa St',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94107,
#   'lat': 37.76311,
#   'long': -122.40095,
#   'numberofyelpreviews': 690,
#   'yelprating': 5},
#  42: {'names': 'Anderson Valley Brewing Company',
#   'address': '17700 Hwy 253',
#   'businesstype': 'Breweries',
#   'city': 'Boonville',
#   'zip': 95415,
#   'lat': 39.001377,
#   'long': -123.356019,
#   'numberofyelpreviews': 228,
#   'yelprating': 4},
#  43: {'names': 'Angel City Brewery',
#   'address': '216 Alameda St',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90012,
#   'lat': 34.0465361,
#   'long': -118.2378194,
#   'numberofyelpreviews': 1747,
#   'yelprating': 4},
#  44: {'names': 'Angry Horse Brewing',
#   'address': '603 W Whittier Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Montebello',
#   'zip': 90640,
#   'lat': 34.0095721,
#   'long': -118.1063421,
#   'numberofyelpreviews': 117,
#   'yelprating': 4},
#  45: {'names': 'Anchor Brewing Company',
#   'address': '1705 Mariposa St',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94107,
#   'lat': 37.76311,
#   'long': -122.40095,
#   'numberofyelpreviews': 690,
#   'yelprating': 5},
#  46: {'names': 'Golden Road Brewing',
#   'address': '5410 W San Fernando Rd',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90039,
#   'lat': 34.15064,
#   'long': -118.274453,
#   'numberofyelpreviews': 2296,
#   'yelprating': 4},
#  47: {'names': 'Arcana Brewing Company',
#   'address': '5621 Palmer Way',
#   'businesstype': 'Breweries',
#   'city': 'Carlsbad',
#   'zip': 92010,
#   'lat': 33.14013407,
#   'long': -117.27389,
#   'numberofyelpreviews': 94,
#   'yelprating': 4.5},
#  48: {'names': 'Centro',
#   'address': '140 E Main St',
#   'businesstype': 'Breweries',
#   'city': 'Tustin',
#   'zip': 92780,
#   'lat': 33.7419509,
#   'long': -117.8231295,
#   'numberofyelpreviews': 419,
#   'yelprating': 4.5},
#  49: {'names': 'Armistice Brewing Company',
#   'address': '845 Marina Bay Pkwy',
#   'businesstype': 'Breweries',
#   'city': 'Richmond',
#   'zip': 94804,
#   'lat': 37.91944179,
#   'long': -122.3482621,
#   'numberofyelpreviews': 102,
#   'yelprating': 4.5},
#  50: {'names': 'Armstrong Brewing',
#   'address': '415 Grand Ave',
#   'businesstype': 'Breweries',
#   'city': 'South San Francisco',
#   'zip': 94080,
#   'lat': 37.65578812,
#   'long': -122.413363,
#   'numberofyelpreviews': 134,
#   'yelprating': 4.5},
#  51: {'names': 'Arrow Lodge Brewing',
#   'address': '720 E Arrow Hwy',
#   'businesstype': 'Breweries',
#   'city': 'Covina',
#   'zip': 91722,
#   'lat': 34.10506357,
#   'long': -117.8765008,
#   'numberofyelpreviews': 153,
#   'yelprating': 4},
#  52: {'names': 'Artifex Brewing Company',
#   'address': '919 Calle Amanecer',
#   'businesstype': 'Breweries',
#   'city': 'San Clemente',
#   'zip': 92673,
#   'lat': 33.448949,
#   'long': -117.6059392,
#   'numberofyelpreviews': 134,
#   'yelprating': 4.5},
#  53: {'names': 'Asian Brothers Brewing Company',
#   'address': '4800 Florin Rd',
#   'businesstype': 'Breweries',
#   'city': 'Sacramento',
#   'zip': 95823,
#   'lat': 38.49552,
#   'long': -121.4492,
#   'numberofyelpreviews': 17,
#   'yelprating': 4},
#  54: {'names': 'Asylum Brewing',
#   'address': '2970 E La Palma Ave',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92806,
#   'lat': 33.84935,
#   'long': -117.86094,
#   'numberofyelpreviews': 60,
#   'yelprating': 4},
#  55: {'names': 'At Ease Brewing',
#   'address': '1825 I St',
#   'businesstype': 'Breweries',
#   'city': 'Sacramento',
#   'zip': 95811,
#   'lat': 38.57853,
#   'long': -121.48095,
#   'numberofyelpreviews': 16,
#   'yelprating': 5},
#  56: {'names': 'Aztec Brewery',
#   'address': '2330 La Mirada Dr',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.15014,
#   'long': -117.2298,
#   'numberofyelpreviews': 133,
#   'yelprating': 4},
#  57: {'names': 'Backstreet Brewery',
#   'address': '1884 S Santa Cruz St',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92805,
#   'lat': 33.8006007,
#   'long': -117.8959266,
#   'numberofyelpreviews': 186,
#   'yelprating': 4.5},
#  58: {'names': 'Bagby Beer Company',
#   'address': '601 S Coast Hwy',
#   'businesstype': 'Breweries',
#   'city': 'Oceanside',
#   'zip': 92054,
#   'lat': 33.18923,
#   'long': -117.37426,
#   'numberofyelpreviews': 1110,
#   'yelprating': 4},
#  59: {'names': 'Home Brew Mart - Ballast Point',
#   'address': '5401 Linda Vista Rd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92110,
#   'lat': 32.76678416,
#   'long': -117.1952391,
#   'numberofyelpreviews': 447,
#   'yelprating': 4},
#  60: {'names': 'Ballast Point Long Beach',
#   'address': '110 N Marina Dr',
#   'businesstype': 'Breweries',
#   'city': 'Long Beach',
#   'zip': 90803,
#   'lat': 33.74591428,
#   'long': -118.1145454,
#   'numberofyelpreviews': 2212,
#   'yelprating': 3.5},
#  61: {'names': 'Ballast Point Anaheim',
#   'address': '1540 S Disneyland Dr',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92802,
#   'lat': 33.8086987,
#   'long': -117.9238651,
#   'numberofyelpreviews': 359,
#   'yelprating': 3},
#  62: {'names': 'Ballast Point Little Italy',
#   'address': '2215 India St',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92101,
#   'lat': 32.72752135,
#   'long': -117.1698137,
#   'numberofyelpreviews': 1765,
#   'yelprating': 4.5},
#  63: {'names': 'Standard Deviant Brewing',
#   'address': '280 14th St',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94103,
#   'lat': 37.76849,
#   'long': -122.41949,
#   'numberofyelpreviews': 128,
#   'yelprating': 4.5},
#  64: {'names': 'Bang The Drum Brewery',
#   'address': '950 Orcutt Rd',
#   'businesstype': 'Breweries',
#   'city': 'San Luis Obispo',
#   'zip': 93401,
#   'lat': 35.26150611,
#   'long': -120.6458144,
#   'numberofyelpreviews': 116,
#   'yelprating': 4},
#  65: {'names': 'Barebottle Brewing Company',
#   'address': '1525 Cortland Ave',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94110,
#   'lat': 37.7400856,
#   'long': -122.4090042,
#   'numberofyelpreviews': 360,
#   'yelprating': 4.5},
#  66: {'names': 'Barley Forge Brewing',
#   'address': '2957 Randolph Ave',
#   'businesstype': 'Breweries',
#   'city': 'Costa Mesa',
#   'zip': 92626,
#   'lat': 33.67878,
#   'long': -117.88822,
#   'numberofyelpreviews': 714,
#   'yelprating': 4.5},
#  67: {'names': 'BarmHaus Brewing',
#   'address': '3782 Winding Creek Ln',
#   'businesstype': 'Breweries',
#   'city': 'Garden Valley',
#   'zip': 95633,
#   'lat': 38.84013,
#   'long': -120.87859,
#   'numberofyelpreviews': 5,
#   'yelprating': 4.5},
#  68: {'names': 'Belching Beaver Pub980',
#   'address': '980 Park Center Dr',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.1449654,
#   'long': -117.2287423,
#   'numberofyelpreviews': 423,
#   'yelprating': 4.5},
#  69: {'names': 'Barrel Head Brewhouse',
#   'address': '1785 Fulton St',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94117,
#   'lat': 37.77575218,
#   'long': -122.4460322,
#   'numberofyelpreviews': 515,
#   'yelprating': 4},
#  70: {'names': 'BarrelHouse Brewing Co',
#   'address': '3055 Limestone Way',
#   'businesstype': 'Breweries',
#   'city': 'Paso Robles',
#   'zip': 93446,
#   'lat': 35.57611408,
#   'long': -120.691105,
#   'numberofyelpreviews': 324,
#   'yelprating': 4.5},
#  71: {'names': 'Bartlett Hall',
#   'address': "242 O'Farrell St",
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94102,
#   'lat': 37.78637792,
#   'long': -122.4087232,
#   'numberofyelpreviews': 810,
#   'yelprating': 3.5},
#  72: {'names': 'BattleMage Brewing Company',
#   'address': '2870 Scott St',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.14017868,
#   'long': -117.2276154,
#   'numberofyelpreviews': 92,
#   'yelprating': 5},
#  73: {'names': 'Bay Bridge Brewing',
#   'address': '688 Marsat Ct',
#   'businesstype': 'Breweries',
#   'city': 'Chula Vista',
#   'zip': 91911,
#   'lat': 32.6009521,
#   'long': -117.082695,
#   'numberofyelpreviews': 54,
#   'yelprating': 4.5},
#  74: {'names': 'Bay City Brewing Company',
#   'address': '3760 Hancock St',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92110,
#   'lat': 32.75821841,
#   'long': -117.2117588,
#   'numberofyelpreviews': 128,
#   'yelprating': 4.5},
#  75: {'names': 'Park Chalet Coastal Beer Garden',
#   'address': '1000 Great Hwy',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94121,
#   'lat': 37.76949839,
#   'long': -122.5102007,
#   'numberofyelpreviews': 1296,
#   'yelprating': 3},
#  76: {'names': 'Beach Grease Beer Company',
#   'address': '1280 Activity Dr',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.14185,
#   'long': -117.2194,
#   'numberofyelpreviews': 34,
#   'yelprating': 4.5},
#  77: {'names': 'Beachwood Blendery',
#   'address': '247 N Long Beach Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Long Beach',
#   'zip': 90802,
#   'lat': 33.77025,
#   'long': -118.18975,
#   'numberofyelpreviews': 79,
#   'yelprating': 4.5},
#  78: {'names': 'Beachwood Brewing Taproom',
#   'address': '7631 Woodwind Dr',
#   'businesstype': 'Breweries',
#   'city': 'Huntington Beach',
#   'zip': 92647,
#   'lat': 33.70431886,
#   'long': -117.9954395,
#   'numberofyelpreviews': 55,
#   'yelprating': 4.5},
#  79: {'names': 'Dust Bowl Brewery Taproom',
#   'address': '3000 Fulkerth Rd',
#   'businesstype': 'Breweries',
#   'city': 'Turlock',
#   'zip': 95380,
#   'lat': 37.50673791,
#   'long': -120.8827626,
#   'numberofyelpreviews': 648,
#   'yelprating': 3.5},
#  80: {'names': 'Belching Beaver Brewery - Oceanside',
#   'address': '1334 Rocky Point Dr',
#   'businesstype': 'Breweries',
#   'city': 'Oceanside',
#   'zip': 92056,
#   'lat': 33.21252519,
#   'long': -117.291587,
#   'numberofyelpreviews': 71,
#   'yelprating': 4},
#  81: {'names': 'Belching Beaver Brewery Tavern & Grill',
#   'address': '302 E Broadway',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92084,
#   'lat': 33.2021,
#   'long': -117.24113,
#   'numberofyelpreviews': 659,
#   'yelprating': 4},
#  82: {'names': 'Belching Beaver Pub980',
#   'address': '980 Park Center Dr',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.1449654,
#   'long': -117.2287423,
#   'numberofyelpreviews': 423,
#   'yelprating': 4.5},
#  83: {'names': 'Belmont Brewing',
#   'address': '25 39th Pl',
#   'businesstype': 'Breweries',
#   'city': 'Long Beach',
#   'zip': 90803,
#   'lat': 33.759361,
#   'long': -118.148117,
#   'numberofyelpreviews': 1480,
#   'yelprating': 3.5},
#  84: {'names': 'Benoit-Casper Brewing',
#   'address': '1201 Pennsylvania Ave',
#   'businesstype': 'Breweries',
#   'city': 'Richmond',
#   'zip': 94801,
#   'lat': 37.94241,
#   'long': -122.35796,
#   'numberofyelpreviews': 22,
#   'yelprating': 4.5},
#  85: {'names': 'Berryessa Brewing Company',
#   'address': '27260 Hwy 128',
#   'businesstype': 'Breweries',
#   'city': 'Winters',
#   'zip': 95694,
#   'lat': 38.51468952,
#   'long': -122.0024288,
#   'numberofyelpreviews': 164,
#   'yelprating': 4.5},
#  86: {'names': 'Big Bear Lake Brewing Company',
#   'address': '40827 Stone Rd',
#   'businesstype': 'Breweries',
#   'city': 'Big Bear Lake',
#   'zip': 92315,
#   'lat': 34.242516,
#   'long': -116.911008,
#   'numberofyelpreviews': 1421,
#   'yelprating': 3.5},
#  87: {'names': 'Big Meadow Brewing',
#   'address': '241 Main St',
#   'businesstype': 'Breweries',
#   'city': 'Bridgeport',
#   'zip': 93517,
#   'lat': 38.25569307,
#   'long': -119.2277017,
#   'numberofyelpreviews': 17,
#   'yelprating': 5},
#  88: {'names': 'Big Sexy Brewing Company',
#   'address': '5861 88th St',
#   'businesstype': 'Breweries',
#   'city': 'Sacramento',
#   'zip': 95828,
#   'lat': 38.5201,
#   'long': -121.37519,
#   'numberofyelpreviews': 64,
#   'yelprating': 4.5},
#  89: {'names': 'Big Stump Brew Company',
#   'address': '1716 L St',
#   'businesstype': 'Breweries',
#   'city': 'Sacramento',
#   'zip': 95811,
#   'lat': 38.57523873,
#   'long': -121.4842339,
#   'numberofyelpreviews': 142,
#   'yelprating': 4.5},
#  90: {'names': 'Bike Dog Brewing Co',
#   'address': '2534 Industrial Blvd',
#   'businesstype': 'Breweries',
#   'city': 'West Sacramento',
#   'zip': 95691,
#   'lat': 38.566263,
#   'long': -121.543518,
#   'numberofyelpreviews': 203,
#   'yelprating': 4.5},
#  91: {'names': 'Bird Street Brewing',
#   'address': '242 Heinlen St',
#   'businesstype': 'Breweries',
#   'city': 'Lemoore',
#   'zip': 93245,
#   'lat': 36.30155,
#   'long': -119.78457,
#   'numberofyelpreviews': 7,
#   'yelprating': 4.5},
#  92: {'names': 'Bitter Brothers Brewing',
#   'address': '4170 Morena Blvd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92117,
#   'lat': 32.81589754,
#   'long': -117.2202024,
#   'numberofyelpreviews': 88,
#   'yelprating': 4.5},
#  93: {'names': 'Black Cock Brewing Company',
#   'address': '1444 N Batavia St',
#   'businesstype': 'Breweries',
#   'city': 'Orange',
#   'zip': 92867,
#   'lat': 33.8113642,
#   'long': -117.8625749,
#   'numberofyelpreviews': 263,
#   'yelprating': 4},
#  94: {'names': 'Black Doubt Brewing Company',
#   'address': '452 Old Mammoth Rd',
#   'businesstype': 'Breweries',
#   'city': 'Mammoth Lakes',
#   'zip': 93546,
#   'lat': 37.63938,
#   'long': -118.96724,
#   'numberofyelpreviews': 135,
#   'yelprating': 5},
#  95: {'names': 'Black Gold Brewing Company',
#   'address': '508 Center St',
#   'businesstype': 'Breweries',
#   'city': 'Taft',
#   'zip': 93268,
#   'lat': 35.1412097,
#   'long': -119.4594135,
#   'numberofyelpreviews': 58,
#   'yelprating': 4},
#  96: {'names': 'Black Hammer Brewing',
#   'address': '544 Bryant St',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94107,
#   'lat': 37.7807,
#   'long': -122.39701,
#   'numberofyelpreviews': 314,
#   'yelprating': 4.5},
#  97: {'names': 'Black Market Brewing Co. - Temecula',
#   'address': '41740 Enterprise Cir N',
#   'businesstype': 'Breweries',
#   'city': 'Temecula',
#   'zip': 92590,
#   'lat': 33.51854,
#   'long': -117.16959,
#   'numberofyelpreviews': 273,
#   'yelprating': 4},
#  98: {'names': 'BLACK PLAGUE Brewing',
#   'address': '2550 Jason Ct',
#   'businesstype': 'Breweries',
#   'city': 'Oceanside',
#   'zip': 92056,
#   'lat': 33.21564,
#   'long': -117.2668,
#   'numberofyelpreviews': 137,
#   'yelprating': 4.5},
#  99: {'names': 'Blaker Brewing',
#   'address': '1063 Montclaire Dr',
#   'businesstype': 'Breweries',
#   'city': 'Ceres',
#   'zip': 95307,
#   'lat': 37.57647109,
#   'long': -120.9801945,
#   'numberofyelpreviews': 52,
#   'yelprating': 4.5},
#  100: {'names': 'Heretic Brewing Company',
#   'address': '1052 Horizon Dr',
#   'businesstype': 'Breweries',
#   'city': 'Fairfield',
#   'zip': 94533,
#   'lat': 38.273647,
#   'long': -122.015358,
#   'numberofyelpreviews': 261,
#   'yelprating': 4.5},
#  101: {'names': 'Blue Note Brewing Company',
#   'address': '750 Dead Cat Aly',
#   'businesstype': 'Breweries',
#   'city': 'Woodland',
#   'zip': 95695,
#   'lat': 38.6779499,
#   'long': -121.7712086,
#   'numberofyelpreviews': 88,
#   'yelprating': 4.5},
#  102: {'names': 'Blue Oak Brewing Company',
#   'address': '815 Cherry Ln',
#   'businesstype': 'Breweries',
#   'city': 'San Carlos',
#   'zip': 94070,
#   'lat': 37.510186,
#   'long': -122.253044,
#   'numberofyelpreviews': 64,
#   'yelprating': 4.5},
#  103: {'names': 'BNS Brewing & Distilling',
#   'address': '10960 Wheatlands Ave',
#   'businesstype': 'Breweries',
#   'city': 'Santee',
#   'zip': 92071,
#   'lat': 32.84666,
#   'long': -116.95834,
#   'numberofyelpreviews': 151,
#   'yelprating': 4},
#  104: {'names': 'Bolt Brewery',
#   'address': '8179 Center St',
#   'businesstype': 'Breweries',
#   'city': 'La Mesa',
#   'zip': 91942,
#   'lat': 32.77196926,
#   'long': -117.0205417,
#   'numberofyelpreviews': 232,
#   'yelprating': 4.5},
#  105: {'names': 'Bonaventure Brewing Company',
#   'address': '404 S Figueroa St',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90071,
#   'lat': 34.05256,
#   'long': -118.25601,
#   'numberofyelpreviews': 387,
#   'yelprating': 3},
#  106: {'names': 'Boomtown Brewery',
#   'address': '700 Jackson St',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90012,
#   'lat': 34.05081,
#   'long': -118.23311,
#   'numberofyelpreviews': 354,
#   'yelprating': 4.5},
#  107: {'names': "Bootlegger's Brewery",
#   'address': '130 S Highland Ave',
#   'businesstype': 'Breweries',
#   'city': 'Fullerton',
#   'zip': 92832,
#   'lat': 33.86963,
#   'long': -117.92845,
#   'numberofyelpreviews': 762,
#   'yelprating': 4},
#  108: {'names': "Bootlegger's Brewery",
#   'address': '130 S Highland Ave',
#   'businesstype': 'Breweries',
#   'city': 'Fullerton',
#   'zip': 92832,
#   'lat': 33.86963,
#   'long': -117.92845,
#   'numberofyelpreviews': 762,
#   'yelprating': 4},
#  109: {'names': "Bootlegger's Brewery - Costa Mesa",
#   'address': '696 Randolph Ave',
#   'businesstype': 'Breweries',
#   'city': 'Costa Mesa',
#   'zip': 92626,
#   'lat': 33.6768478,
#   'long': -117.8855811,
#   'numberofyelpreviews': 52,
#   'yelprating': 4.5},
#  110: {'names': 'Ritual Brewing',
#   'address': '1315 Research Dr',
#   'businesstype': 'Breweries',
#   'city': 'Redlands',
#   'zip': 92374,
#   'lat': 34.07057793,
#   'long': -117.2370279,
#   'numberofyelpreviews': 237,
#   'yelprating': 4.5},
#  111: {'names': 'Booze Brothers Brewing',
#   'address': '2545 Progress St',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.148172,
#   'long': -117.218047,
#   'numberofyelpreviews': 242,
#   'yelprating': 4.5},
#  112: {'names': 'Border X Brewing',
#   'address': '2181 Logan Ave',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92113,
#   'lat': 32.69803,
#   'long': -117.13983,
#   'numberofyelpreviews': 285,
#   'yelprating': 4.5},
#  113: {'names': 'Border X Brewing',
#   'address': '2181 Logan Ave',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92113,
#   'lat': 32.69803,
#   'long': -117.13983,
#   'numberofyelpreviews': 285,
#   'yelprating': 4.5},
#  114: {'names': 'Bottle Logic Brewing',
#   'address': '1072 N Armando St',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92806,
#   'lat': 33.849549,
#   'long': -117.859775,
#   'numberofyelpreviews': 705,
#   'yelprating': 4.5},
#  115: {'names': 'Bravery Brewing',
#   'address': '42705 8th St W',
#   'businesstype': 'Breweries',
#   'city': 'Lancaster',
#   'zip': 93534,
#   'lat': 34.658707,
#   'long': -118.145998,
#   'numberofyelpreviews': 139,
#   'yelprating': 4.5},
#  116: {'names': 'Breakwater Brewing Company',
#   'address': '101 N Coast Hwy',
#   'businesstype': 'Breweries',
#   'city': 'Oceanside',
#   'zip': 92054,
#   'lat': 33.1950701,
#   'long': -117.3790501,
#   'numberofyelpreviews': 558,
#   'yelprating': 4},
#  117: {'names': 'Laguna Beach Beer Company - Rancho Santa Margarita',
#   'address': '29851 Aventura D',
#   'businesstype': 'Breweries',
#   'city': 'Rancho Santa Margarita',
#   'zip': 92688,
#   'lat': 33.63661,
#   'long': -117.60958,
#   'numberofyelpreviews': 112,
#   'yelprating': 4.5},
#  118: {'names': 'Three Weavers Brewing Co',
#   'address': '1031 W Manchester Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Inglewood',
#   'zip': 90301,
#   'lat': 33.96154195,
#   'long': -118.3747575,
#   'numberofyelpreviews': 346,
#   'yelprating': 4.5},
#  119: {'names': 'Tilted Mash Brewing',
#   'address': '9175 Union Park Way',
#   'businesstype': 'Breweries',
#   'city': 'Elk Grove',
#   'zip': 95624,
#   'lat': 38.3891154,
#   'long': -121.3606571,
#   'numberofyelpreviews': 112,
#   'yelprating': 4.5},
#  120: {'names': 'MacLeod Ale Brewing',
#   'address': '14741 Calvert St',
#   'businesstype': 'Breweries',
#   'city': 'Van Nuys',
#   'zip': 91411,
#   'lat': 34.18194,
#   'long': -118.45458,
#   'numberofyelpreviews': 381,
#   'yelprating': 4.5},
#  121: {'names': 'Del Cielo Brewing Company',
#   'address': '701 Escobar St',
#   'businesstype': 'Breweries',
#   'city': 'Martinez',
#   'zip': 94553,
#   'lat': 38.0183247,
#   'long': -122.1368987,
#   'numberofyelpreviews': 95,
#   'yelprating': 4},
#  122: {'names': 'Chapman Crafted Beer',
#   'address': '123 N Cypress St',
#   'businesstype': 'Breweries',
#   'city': 'Orange',
#   'zip': 92866,
#   'lat': 33.78860856,
#   'long': -117.8560722,
#   'numberofyelpreviews': 124,
#   'yelprating': 4.5},
#  123: {'names': 'Hamilton Family Brewery',
#   'address': '9757 7th St',
#   'businesstype': 'Breweries',
#   'city': 'Rancho Cucamonga',
#   'zip': 91730,
#   'lat': 34.08804762,
#   'long': -117.5919651,
#   'numberofyelpreviews': 308,
#   'yelprating': 4.5},
#  124: {'names': 'Berryessa Brewing Company',
#   'address': '27260 Hwy 128',
#   'businesstype': 'Breweries',
#   'city': 'Winters',
#   'zip': 95694,
#   'lat': 38.51468952,
#   'long': -122.0024288,
#   'numberofyelpreviews': 164,
#   'yelprating': 4.5},
#  125: {'names': 'Brewery Twenty Five',
#   'address': '106 3rd St',
#   'businesstype': 'Breweries',
#   'city': 'San Juan Bautista',
#   'zip': 95045,
#   'lat': 36.843959,
#   'long': -121.535381,
#   'numberofyelpreviews': 10,
#   'yelprating': 5},
#  126: {'names': 'Brewheim Beer Makers',
#   'address': '1931 E Wright Cir',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92806,
#   'lat': 33.80527601,
#   'long': -117.8906902,
#   'numberofyelpreviews': 99,
#   'yelprating': 4.5},
#  127: {'names': 'Brewing Reserve of California',
#   'address': '2930 College Ave',
#   'businesstype': 'Breweries',
#   'city': 'Costa Mesa',
#   'zip': 92626,
#   'lat': 33.67919,
#   'long': -117.91605,
#   'numberofyelpreviews': 21,
#   'yelprating': 4.5},
#  128: {'names': 'brewLAB',
#   'address': '4191 Carpinteria Ave',
#   'businesstype': 'Breweries',
#   'city': 'Carpinteria',
#   'zip': 93013,
#   'lat': 34.4039078,
#   'long': -119.5341339,
#   'numberofyelpreviews': 44,
#   'yelprating': 4.5},
#  129: {'names': 'Brouwerij West',
#   'address': '110 E 22nd St',
#   'businesstype': 'Breweries',
#   'city': 'San Pedro',
#   'zip': 90731,
#   'lat': 33.7257694,
#   'long': -118.2802782,
#   'numberofyelpreviews': 296,
#   'yelprating': 4.5},
#  130: {'names': 'Bruery Terreux Tasting Room',
#   'address': '1174 N Grove St',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92806,
#   'lat': 33.8575048,
#   'long': -117.8421334,
#   'numberofyelpreviews': 231,
#   'yelprating': 4.5},
#  131: {'names': 'The Bruery',
#   'address': '717 Dunn Way',
#   'businesstype': 'Breweries',
#   'city': 'Placentia',
#   'zip': 92870,
#   'lat': 33.86242873,
#   'long': -117.8792751,
#   'numberofyelpreviews': 957,
#   'yelprating': 4.5},
#  132: {'names': 'Burgeon Beer Co',
#   'address': '6350 Yarrow Dr',
#   'businesstype': 'Breweries',
#   'city': 'Carlsbad',
#   'zip': 92011,
#   'lat': 33.1195647,
#   'long': -117.2732618,
#   'numberofyelpreviews': 155,
#   'yelprating': 4.5},
#  133: {'names': 'Burnin Daylight Brewing',
#   'address': '24516 Narbonne Ave',
#   'businesstype': 'Breweries',
#   'city': 'Lomita',
#   'zip': 90717,
#   'lat': 33.8029046,
#   'long': -118.3197371,
#   'numberofyelpreviews': 46,
#   'yelprating': 4.5},
#  134: {'names': 'Burning Barrel Brewing Company',
#   'address': '11210 Sun Center Dr',
#   'businesstype': 'Breweries',
#   'city': 'Rancho Cordova',
#   'zip': 95742,
#   'lat': 38.5976889,
#   'long': -121.266995,
#   'numberofyelpreviews': 74,
#   'yelprating': 4.5},
#  135: {'names': 'Burning Beard Brewing Company',
#   'address': '785 Vernon Way',
#   'businesstype': 'Breweries',
#   'city': 'El Cajon',
#   'zip': 92020,
#   'lat': 32.81174776,
#   'long': -116.9722861,
#   'numberofyelpreviews': 106,
#   'yelprating': 4.5},
#  136: {'names': 'Faction Brewing',
#   'address': '2501 Monarch St',
#   'businesstype': 'Breweries',
#   'city': 'Alameda',
#   'zip': 94501,
#   'lat': 37.786577,
#   'long': -122.309303,
#   'numberofyelpreviews': 482,
#   'yelprating': 4.5},
#  137: {'names': 'California Wild Ales',
#   'address': '4202 Sorrento Valley Blvd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92121,
#   'lat': 32.90536,
#   'long': -117.21485,
#   'numberofyelpreviews': 31,
#   'yelprating': 5},
#  138: {'names': 'Campbell Brewing Company',
#   'address': '200 E Campbell Ave',
#   'businesstype': 'Breweries',
#   'city': 'Campbell',
#   'zip': 95008,
#   'lat': 37.28667,
#   'long': -121.94639,
#   'numberofyelpreviews': 402,
#   'yelprating': 2.5},
#  139: {'names': "Captain Fatty's Brewery",
#   'address': '6489 Calle Real',
#   'businesstype': 'Breweries',
#   'city': 'Goleta',
#   'zip': 93117,
#   'lat': 34.439349,
#   'long': -119.851617,
#   'numberofyelpreviews': 79,
#   'yelprating': 4.5},
#  140: {'names': 'Carmel Craft Brewing Company',
#   'address': 'Big Sur Barn 3777 The Barnyard',
#   'businesstype': 'Breweries',
#   'city': 'Carmel-by-the-Sea',
#   'zip': 93923,
#   'lat': 36.5404928,
#   'long': -121.9077938,
#   'numberofyelpreviews': 19,
#   'yelprating': 5},
#  141: {'names': 'Casa Agria Specialty Ales',
#   'address': '701 N Del Norte Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Oxnard',
#   'zip': 93030,
#   'lat': 34.207699,
#   'long': -119.128035,
#   'numberofyelpreviews': 77,
#   'yelprating': 4.5},
#  142: {'names': 'Catalina Island Brew House',
#   'address': '417 Crescent Ave',
#   'businesstype': 'Breweries',
#   'city': 'Avalon',
#   'zip': 90704,
#   'lat': 33.34343224,
#   'long': -118.3255062,
#   'numberofyelpreviews': 262,
#   'yelprating': 4.5},
#  143: {'names': 'Cellarmaker Brewing Company',
#   'address': '1150 Howard St',
#   'businesstype': 'Breweries',
#   'city': 'San Francisco',
#   'zip': 94103,
#   'lat': 37.777217,
#   'long': -122.410766,
#   'numberofyelpreviews': 434,
#   'yelprating': 4.5},
#  144: {'names': 'Central Coast Brewing',
#   'address': '1422 Monterey St',
#   'businesstype': 'Breweries',
#   'city': 'San Luis Obispo',
#   'zip': 93401,
#   'lat': 35.285846,
#   'long': -120.655711,
#   'numberofyelpreviews': 235,
#   'yelprating': 4.5},
#  145: {'names': 'Channel Brewing Company',
#   'address': '110 N San Joaquin St',
#   'businesstype': 'Breweries',
#   'city': 'Stockton',
#   'zip': 95202,
#   'lat': 37.954521,
#   'long': -121.2873039,
#   'numberofyelpreviews': 40,
#   'yelprating': 4},
#  146: {'names': 'Chapman Crafted Beer',
#   'address': '123 N Cypress St',
#   'businesstype': 'Breweries',
#   'city': 'Orange',
#   'zip': 92866,
#   'lat': 33.78860856,
#   'long': -117.8560722,
#   'numberofyelpreviews': 124,
#   'yelprating': 4.5},
#  147: {'names': "Bootlegger's Brewery",
#   'address': '130 S Highland Ave',
#   'businesstype': 'Breweries',
#   'city': 'Fullerton',
#   'zip': 92832,
#   'lat': 33.86963,
#   'long': -117.92845,
#   'numberofyelpreviews': 762,
#   'yelprating': 4},
#  148: {'names': 'Chino Valley Brewery',
#   'address': '1609 S Grove Ave',
#   'businesstype': 'Breweries',
#   'city': 'Ontario',
#   'zip': 91761,
#   'lat': 34.0443303,
#   'long': -117.6272851,
#   'numberofyelpreviews': 50,
#   'yelprating': 4.5},
#  149: {'names': 'Chula Vista Brewery',
#   'address': '294 3rd Ave',
#   'businesstype': 'Breweries',
#   'city': 'Chula Vista',
#   'zip': 91910,
#   'lat': 32.64163405,
#   'long': -117.0802618,
#   'numberofyelpreviews': 76,
#   'yelprating': 4},
#  150: {'names': 'Circle 9 Brewing',
#   'address': '7292 Opportunity Rd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92111,
#   'lat': 32.8254665,
#   'long': -117.160549,
#   'numberofyelpreviews': 50,
#   'yelprating': 4.5},
#  151: {'names': 'Cismontane Brewing Company',
#   'address': '1409 E Warner Ave',
#   'businesstype': 'Breweries',
#   'city': 'Santa Ana',
#   'zip': 92688,
#   'lat': 33.71638,
#   'long': -117.85177,
#   'numberofyelpreviews': 119,
#   'yelprating': 4},
#  152: {'names': 'Citizen Brewers',
#   'address': '5837 Mission Gorge Rd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92120,
#   'lat': 32.7815593,
#   'long': -117.1008159,
#   'numberofyelpreviews': 17,
#   'yelprating': 5},
#  153: {'names': 'Claimstake Brewing',
#   'address': '11366 Monier Park Pl',
#   'businesstype': 'Breweries',
#   'city': 'Rancho Cordova',
#   'zip': 95742,
#   'lat': 38.58213,
#   'long': -121.26083,
#   'numberofyelpreviews': 115,
#   'yelprating': 4.5},
#  154: {'names': 'Clandestine Brewing',
#   'address': '980 S First St',
#   'businesstype': 'Breweries',
#   'city': 'San Jose',
#   'zip': 95110,
#   'lat': 37.32158,
#   'long': -121.87872,
#   'numberofyelpreviews': 66,
#   'yelprating': 4.5},
#  155: {'names': 'Cleophus Quealy',
#   'address': '448 Hester St',
#   'businesstype': 'Breweries',
#   'city': 'San Leandro',
#   'zip': 94577,
#   'lat': 37.7221819,
#   'long': -122.1912972,
#   'numberofyelpreviews': 132,
#   'yelprating': 4.5},
#  156: {'names': 'Coachella Valley Brewing',
#   'address': '30640 Gunther St',
#   'businesstype': 'Breweries',
#   'city': 'Thousand Palms',
#   'zip': 92276,
#   'lat': 33.826594,
#   'long': -116.401405,
#   'numberofyelpreviews': 156,
#   'yelprating': 4},
#  157: {'names': 'Common Space Brewery',
#   'address': '3411 W El Segundo Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Hawthorne',
#   'zip': 90250,
#   'lat': 33.91695,
#   'long': -118.33343,
#   'numberofyelpreviews': 105,
#   'yelprating': 4.5},
#  158: {'names': 'Home Brew Mart - Ballast Point',
#   'address': '5401 Linda Vista Rd',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92110,
#   'lat': 32.76678416,
#   'long': -117.1952391,
#   'numberofyelpreviews': 447,
#   'yelprating': 4},
#  159: {'names': 'Cooperage Brewing Company',
#   'address': '981 Airway Ct',
#   'businesstype': 'Breweries',
#   'city': 'Santa Rosa',
#   'zip': 95403,
#   'lat': 38.475267,
#   'long': -122.735473,
#   'numberofyelpreviews': 139,
#   'yelprating': 4.5},
#  160: {'names': 'Coronado Brewing Company',
#   'address': '875 Seacoast Dr',
#   'businesstype': 'Breweries',
#   'city': 'Imperial Beach',
#   'zip': 91932,
#   'lat': 32.5805081,
#   'long': -117.1315951,
#   'numberofyelpreviews': 386,
#   'yelprating': 4},
#  161: {'names': 'Coronado Brewing Company',
#   'address': '875 Seacoast Dr',
#   'businesstype': 'Breweries',
#   'city': 'Imperial Beach',
#   'zip': 91932,
#   'lat': 32.5805081,
#   'long': -117.1315951,
#   'numberofyelpreviews': 386,
#   'yelprating': 4},
#  162: {'names': 'Corralitos Brewing Company',
#   'address': '2536 Freedom Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Watsonville',
#   'zip': 95076,
#   'lat': 36.94997196,
#   'long': -121.793,
#   'numberofyelpreviews': 75,
#   'yelprating': 4.5},
#  163: {'names': 'Cosmic Brewery',
#   'address': '20316 Gramercy Pl',
#   'businesstype': 'Breweries',
#   'city': 'Torrance',
#   'zip': 90501,
#   'lat': 33.84627828,
#   'long': -118.3113991,
#   'numberofyelpreviews': 111,
#   'yelprating': 4},
#  164: {'names': 'Craft Brewing Company - Lake Elsinore',
#   'address': '530 Crane St',
#   'businesstype': 'Breweries',
#   'city': 'Lake Elsinore',
#   'zip': 92530,
#   'lat': 33.68678,
#   'long': -117.33991,
#   'numberofyelpreviews': 103,
#   'yelprating': 4.5},
#  165: {'names': 'Craftsman Brewing Company',
#   'address': '1260 Lincoln Ave',
#   'businesstype': 'Breweries',
#   'city': 'Pasadena',
#   'zip': 91103,
#   'lat': 34.1677048,
#   'long': -118.1594351,
#   'numberofyelpreviews': 39,
#   'yelprating': 4.5},
#  166: {'names': 'Crooked Lane Brewing',
#   'address': '536 Grass Valley Hwy',
#   'businesstype': 'Breweries',
#   'city': 'Auburn',
#   'zip': 95603,
#   'lat': 38.90943909,
#   'long': -121.0763931,
#   'numberofyelpreviews': 136,
#   'yelprating': 4.5},
#  167: {'names': 'Culture Brewing Co - Solana Beach',
#   'address': '111 S Cedros Ave',
#   'businesstype': 'Breweries',
#   'city': 'Solana Beach',
#   'zip': 92075,
#   'lat': 32.9915933,
#   'long': -117.2707002,
#   'numberofyelpreviews': 324,
#   'yelprating': 4.5},
#  168: {'names': 'Culver Beer Company',
#   'address': '2719 W Loker Ave',
#   'businesstype': 'Breweries',
#   'city': 'Carlsbad',
#   'zip': 92010,
#   'lat': 33.13264084,
#   'long': -117.2584,
#   'numberofyelpreviews': 88,
#   'yelprating': 5},
#  169: {'names': 'Dead Oak Brewing Company',
#   'address': '5925 Entrada Ave',
#   'businesstype': 'Breweries',
#   'city': 'Atascadero',
#   'zip': 93422,
#   'lat': 35.48974222,
#   'long': -120.668791,
#   'numberofyelpreviews': 34,
#   'yelprating': 4.5},
#  170: {'names': 'Death Valley Brewery',
#   'address': '102 Old Spanish Trl',
#   'businesstype': 'Breweries',
#   'city': 'Tecopa',
#   'zip': 92389,
#   'lat': 35.84818656,
#   'long': -116.2265261,
#   'numberofyelpreviews': 12,
#   'yelprating': 4.5},
#  171: {'names': 'Deft Brewing',
#   'address': '5328 Banks St',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92110,
#   'lat': 32.76436,
#   'long': -117.19906,
#   'numberofyelpreviews': 71,
#   'yelprating': 5},
#  172: {'names': 'Del Cielo Brewing Company',
#   'address': '701 Escobar St',
#   'businesstype': 'Breweries',
#   'city': 'Martinez',
#   'zip': 94553,
#   'lat': 38.0183247,
#   'long': -122.1368987,
#   'numberofyelpreviews': 95,
#   'yelprating': 4},
#  173: {'names': 'Brew Crew',
#   'address': '11626 Sterling Ave',
#   'businesstype': 'Breweries',
#   'city': 'Riverside',
#   'zip': 92503,
#   'lat': 33.895437,
#   'long': -117.484886,
#   'numberofyelpreviews': 56,
#   'yelprating': 4.5},
#  174: {'names': "Devil's Canyon Brewing Company",
#   'address': '935 Washington St',
#   'businesstype': 'Breweries',
#   'city': 'San Carlos',
#   'zip': 94070,
#   'lat': 37.49851,
#   'long': -122.24381,
#   'numberofyelpreviews': 161,
#   'yelprating': 4},
#  175: {'names': 'Temblor Brewing Company',
#   'address': '3200 Buck Owens Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Bakersfield',
#   'zip': 93308,
#   'lat': 35.38877,
#   'long': -119.04222,
#   'numberofyelpreviews': 536,
#   'yelprating': 4},
#  176: {'names': 'Discretion Brewing',
#   'address': '2703 41st Ave',
#   'businesstype': 'Breweries',
#   'city': 'Soquel',
#   'zip': 95073,
#   'lat': 36.98567182,
#   'long': -121.9654715,
#   'numberofyelpreviews': 334,
#   'yelprating': 4},
#  177: {'names': 'Bottle Logic Brewing',
#   'address': '1072 N Armando St',
#   'businesstype': 'Breweries',
#   'city': 'Anaheim',
#   'zip': 92806,
#   'lat': 33.849549,
#   'long': -117.859775,
#   'numberofyelpreviews': 705,
#   'yelprating': 4.5},
#  178: {'names': 'Diving Dog Brewhouse',
#   'address': '1802 Telegraph Ave',
#   'businesstype': 'Breweries',
#   'city': 'Oakland',
#   'zip': 94612,
#   'lat': 37.8075774,
#   'long': -122.269898,
#   'numberofyelpreviews': 150,
#   'yelprating': 4},
#  179: {'names': 'Division 23 Brewing',
#   'address': '7408 Trade St',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92121,
#   'lat': 32.89034,
#   'long': -117.1629,
#   'numberofyelpreviews': 77,
#   'yelprating': 4.5},
#  180: {'names': 'Docent Brewing',
#   'address': '33049 Calle Aviador',
#   'businesstype': 'Breweries',
#   'city': 'San Juan Capistrano',
#   'zip': 92675,
#   'lat': 33.48328457,
#   'long': -117.6758341,
#   'numberofyelpreviews': 283,
#   'yelprating': 4.5},
#  181: {'names': 'Dos Desperados Brewery',
#   'address': '1241 Linda Vista Dr',
#   'businesstype': 'Breweries',
#   'city': 'San Marcos',
#   'zip': 92078,
#   'lat': 33.137111,
#   'long': -117.1937063,
#   'numberofyelpreviews': 90,
#   'yelprating': 4.5},
#  182: {'names': 'Stumblefoot Brewing Company',
#   'address': '1784 La Costa Meadows Dr',
#   'businesstype': 'Breweries',
#   'city': 'San Marcos',
#   'zip': 92078,
#   'lat': 33.10471682,
#   'long': -117.2192291,
#   'numberofyelpreviews': 108,
#   'yelprating': 4},
#  183: {'names': "Downtown Joe's Brewery and Restaurant",
#   'address': '902 Main St',
#   'businesstype': 'Breweries',
#   'city': 'Napa',
#   'zip': 94559,
#   'lat': 38.29878,
#   'long': -122.2848,
#   'numberofyelpreviews': 827,
#   'yelprating': 3.5},
#  184: {'names': "Dragon's Tale Brewery",
#   'address': '8920 Vernon Ave',
#   'businesstype': 'Breweries',
#   'city': 'Montclair',
#   'zip': 91763,
#   'lat': 34.09150695,
#   'long': -117.6869752,
#   'numberofyelpreviews': 72,
#   'yelprating': 4.5},
#  185: {'names': "Drake's Brewing",
#   'address': '1933 Davis St',
#   'businesstype': 'Breweries',
#   'city': 'San Leandro',
#   'zip': 94577,
#   'lat': 37.71471796,
#   'long': -122.179305,
#   'numberofyelpreviews': 720,
#   'yelprating': 4},
#  186: {'names': 'Draughtsmen Aleworks',
#   'address': '53 Santa Felicia Dr',
#   'businesstype': 'Breweries',
#   'city': 'Goleta',
#   'zip': 93117,
#   'lat': 34.43225145,
#   'long': -119.8760843,
#   'numberofyelpreviews': 69,
#   'yelprating': 5},
#  187: {'names': 'Dreaming Dog Brewery',
#   'address': '2501 W Taron Ct',
#   'businesstype': 'Breweries',
#   'city': 'Elk Grove',
#   'zip': 95757,
#   'lat': 38.4074,
#   'long': -121.47784,
#   'numberofyelpreviews': 57,
#   'yelprating': 3.5},
#  188: {'names': 'Dry River Brewing',
#   'address': '671 S Anderson St',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90023,
#   'lat': 34.03589405,
#   'long': -118.2234941,
#   'numberofyelpreviews': 58,
#   'yelprating': 4},
#  189: {'names': 'Duck Foot Brewing Company',
#   'address': '8920 Kenamar Dr',
#   'businesstype': 'Breweries',
#   'city': 'San Diego',
#   'zip': 92121,
#   'lat': 32.885171,
#   'long': -117.15632,
#   'numberofyelpreviews': 234,
#   'yelprating': 4.5},
#  190: {'names': "The Dudes' Brewing Company",
#   'address': '1840 W 208th St',
#   'businesstype': 'Breweries',
#   'city': 'Torrance',
#   'zip': 90501,
#   'lat': 33.84163,
#   'long': -118.31138,
#   'numberofyelpreviews': 343,
#   'yelprating': 4},
#  191: {'names': 'Crooked Lane Brewing',
#   'address': '536 Grass Valley Hwy',
#   'businesstype': 'Breweries',
#   'city': 'Auburn',
#   'zip': 95603,
#   'lat': 38.90943909,
#   'long': -121.0763931,
#   'numberofyelpreviews': 136,
#   'yelprating': 4.5},
#  192: {'names': 'Dunsmuir Brewery Works',
#   'address': '5701 Dunsmuir Ave',
#   'businesstype': 'Breweries',
#   'city': 'Dunsmuir',
#   'zip': 96025,
#   'lat': 41.21195,
#   'long': -122.2718,
#   'numberofyelpreviews': 296,
#   'yelprating': 4.5},
#  193: {'names': 'Dust Bowl Brewery Taproom',
#   'address': '3000 Fulkerth Rd',
#   'businesstype': 'Breweries',
#   'city': 'Turlock',
#   'zip': 95380,
#   'lat': 37.50673791,
#   'long': -120.8827626,
#   'numberofyelpreviews': 648,
#   'yelprating': 3.5},
#  194: {'names': "Dutch's Brewhouse",
#   'address': '4244 Atlantic Ave',
#   'businesstype': 'Breweries',
#   'city': 'Long Beach',
#   'zip': 90807,
#   'lat': 33.833587,
#   'long': -118.184716,
#   'numberofyelpreviews': 228,
#   'yelprating': 5},
#  195: {'names': 'E.J. Phair Brewing Company',
#   'address': '300 Cumberland St',
#   'businesstype': 'Breweries',
#   'city': 'Pittsburg',
#   'zip': 94565,
#   'lat': 38.03302,
#   'long': -121.88251,
#   'numberofyelpreviews': 227,
#   'yelprating': 4},
#  196: {'names': 'Eagle Rock Brewery',
#   'address': '3056 Roswell St',
#   'businesstype': 'Breweries',
#   'city': 'Los Angeles',
#   'zip': 90065,
#   'lat': 34.11494,
#   'long': -118.24334,
#   'numberofyelpreviews': 414,
#   'yelprating': 4.5},
#  197: {'names': 'Earth and Fire Brewing Company',
#   'address': '825 Riverside Ave',
#   'businesstype': 'Breweries',
#   'city': 'Paso Robles',
#   'zip': 93446,
#   'lat': 35.62375238,
#   'long': -120.6867805,
#   'numberofyelpreviews': 55,
#   'yelprating': 4.5},
#  198: {'names': 'East Brother Beer Company',
#   'address': '1001 Canal Blvd',
#   'businesstype': 'Breweries',
#   'city': 'Richmond',
#   'zip': 94804,
#   'lat': 37.91757584,
#   'long': -122.3753738,
#   'numberofyelpreviews': 96,
#   'yelprating': 4.5},
#  199: {'names': 'East Cliff Brewing Company',
#   'address': '21517 E Cliff Dr',
#   'businesstype': 'Breweries',
#   'city': 'Santa Cruz',
#   'zip': 95062,
#   'lat': 36.96452739,
#   'long': -121.9892458,
#   'numberofyelpreviews': 64,
#   'yelprating': 4.5},
#  200: {'names': 'Ebullition Brew Works',
#   'address': '2449 Cades Way',
#   'businesstype': 'Breweries',
#   'city': 'Vista',
#   'zip': 92081,
#   'lat': 33.15371792,
#   'long': -117.2240165,
#   'numberofyelpreviews': 49,
#   'yelprating': 4.5},
#  201: {'names': 'Redwood Curtain Brewing Company',
#   'address': '550 S G St',
#   'businesstype': 'Breweries',
#   'city': 'Arcata',
# ...
#   'address': '1026 Machin Ave',
#   'businesstype': 'Wineries',
#   'city': 'Novato',
#   'zip': 94945,
#   'lat': 38.10868454,
#   'long': -122.5688171,
#   'numberofyelpreviews': 67,
#   'yelprating': 4.5},
#  934: {'names': 'Vineyard Gate',
#   'address': '238 Broadway',
#   'businesstype': 'Beer, Wine & Spirits',
#   'city': 'Millbrae',
#   'zip': 94030,
#   'lat': 37.60049,
#   'long': -122.39088,
#   'numberofyelpreviews': 18,
#   'yelprating': 4.5},
#  935: {'names': 'Point Reyes Vineyards',
#   'address': '12700 Hwy 1',
#   'businesstype': 'Wineries',
#   'city': 'Point Reyes Station',
#   'zip': 94956,
#   'lat': 38.094045,
#   'long': -122.816176,
#   'numberofyelpreviews': 37,
#   'yelprating': 4},
#  936: {'names': 'Backstage Winery',
#   'address': '295 Magnolia Ave',
#   'businesstype': 'Wineries',
#   'city': 'Larkspur',
#   'zip': 94939,
#   'lat': 37.933481,
#   'long': -122.535877,
#   'numberofyelpreviews': 104,
#   'yelprating': 4.5},
#  937: {'names': 'Ross Valley Players',
#   'address': 'Marin Art & Garden C',
#   'businesstype': 'Performing Arts',
#   'city': 'Ross',
#   'zip': 94957,
#   'lat': 37.96329966,
#   'long': -122.5550222,
#   'numberofyelpreviews': 8,
#   'yelprating': 4.5},
#  938: {'names': 'AppleGarden Cottage',
#   'address': '3875 Tomales-Petaluma Rd',
#   'businesstype': 'Bed & Breakfast',
#   'city': 'Tomales',
#   'zip': 94971,
#   'lat': 38.241825,
#   'long': -122.900232,
#   'numberofyelpreviews': 14,
#   'yelprating': 4.5},
#  939: {'names': 'Butterfly Creek Winery & Vineyards',
#   'address': '4063 Triangle Rd',
#   'businesstype': 'Wineries',
#   'city': 'Mariposa',
#   'zip': 95338,
#   'lat': 37.50160217,
#   'long': -119.86483,
#   'numberofyelpreviews': 10,
#   'yelprating': 4},
#  940: {'names': 'Casto Oaks Fine Wine and Art',
#   'address': '5022 Hwy 140',
#   'businesstype': 'Wineries',
#   'city': 'Mariposa',
#   'zip': 95338,
#   'lat': 37.48447649,
#   'long': -119.9649525,
#   'numberofyelpreviews': 9,
#   'yelprating': 4.5},
#  941: {'names': 'Phillips Hill Winery',
#   'address': '5101 Hwy 128',
#   'businesstype': 'Wine Tasting Room',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.102048,
#   'long': -123.491073,
#   'numberofyelpreviews': 24,
#   'yelprating': 4.5},
#  942: {'names': 'Navarro Vineyards & Winery',
#   'address': '5601 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.09609257,
#   'long': -123.4833392,
#   'numberofyelpreviews': 260,
#   'yelprating': 4.5},
#  943: {'names': 'Drew',
#   'address': '9000 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.059493,
#   'long': -123.434562,
#   'numberofyelpreviews': 19,
#   'yelprating': 4.5},
#  944: {'names': 'Campovida Winery',
#   'address': '13601 Old River Rd',
#   'businesstype': 'Wineries',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.971138,
#   'long': -123.100346,
#   'numberofyelpreviews': 49,
#   'yelprating': 4.5},
#  945: {'names': 'Saracina Vineyards',
#   'address': '11684 S Hwy 101',
#   'businesstype': 'Wine Tours',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.9946,
#   'long': -123.12245,
#   'numberofyelpreviews': 43,
#   'yelprating': 4.5},
#  946: {'names': 'D H Gustafson Family Vineyards',
#   'address': '9100 Stewarts Point Skaggs Springs Rd',
#   'businesstype': 'Wineries',
#   'city': 'Geyserville',
#   'zip': 95441,
#   'lat': 38.67046,
#   'long': -123.03309,
#   'numberofyelpreviews': 39,
#   'yelprating': 5},
#  947: {'names': 'Topel Winery',
#   'address': '125 Matheson St',
#   'businesstype': 'Wineries',
#   'city': 'Healdsburg',
#   'zip': 95448,
#   'lat': 38.6106695,
#   'long': -122.869186,
#   'numberofyelpreviews': 64,
#   'yelprating': 4},
#  948: {'names': 'Beaulieu Vineyard',
#   'address': '1960 Saint Helena Hwy',
#   'businesstype': 'Wineries',
#   'city': 'Rutherford',
#   'zip': 94573,
#   'lat': 38.4593615,
#   'long': -122.423137,
#   'numberofyelpreviews': 343,
#   'yelprating': 4},
#  949: {'names': 'Saracina Vineyards',
#   'address': '11684 S Hwy 101',
#   'businesstype': 'Wine Tours',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.9946,
#   'long': -123.12245,
#   'numberofyelpreviews': 43,
#   'yelprating': 4.5},
#  950: {'names': 'Jaxon Keys Winery & Distillery',
#   'address': '10400 S Hwy 101',
#   'businesstype': 'Distilleries',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 39.013398,
#   'long': -123.128165,
#   'numberofyelpreviews': 56,
#   'yelprating': 4.5},
#  951: {'names': 'Route 128 Vineyards & Winery',
#   'address': '21079 Geyserville Ave',
#   'businesstype': 'Wine Bars',
#   'city': 'Geyserville',
#   'zip': 95441,
#   'lat': 38.7067634,
#   'long': -122.9050961,
#   'numberofyelpreviews': 18,
#   'yelprating': 5},
#  952: {'names': 'Milano Family Winery',
#   'address': '14594 S Highway 101',
#   'businesstype': 'Wineries',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.9578677,
#   'long': -123.1096696,
#   'numberofyelpreviews': 12,
#   'yelprating': 4},
#  953: {'names': "River's End",
#   'address': '11048 Highway 1',
#   'businesstype': 'American (New)',
#   'city': 'Jenner',
#   'zip': 95450,
#   'lat': 38.45055498,
#   'long': -123.1247557,
#   'numberofyelpreviews': 516,
#   'yelprating': 4},
#  954: {'names': 'Rays Station',
#   'address': '13275 Hwy 101',
#   'businesstype': 'Wineries',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.97385,
#   'long': -123.11573,
#   'numberofyelpreviews': 1,
#   'yelprating': 1},
#  955: {'names': 'Lula Cellars',
#   'address': '2800 Guntley Rd',
#   'businesstype': 'Wine Tasting Room',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.122799,
#   'long': -123.516207,
#   'numberofyelpreviews': 54,
#   'yelprating': 5},
#  956: {'names': 'Balo Vineyards',
#   'address': '9001 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.06091,
#   'long': -123.43315,
#   'numberofyelpreviews': 27,
#   'yelprating': 5},
#  957: {'names': 'Navarro Vineyards & Winery',
#   'address': '5601 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.09609257,
#   'long': -123.4833392,
#   'numberofyelpreviews': 260,
#   'yelprating': 4.5},
#  958: {'names': 'Witching Stick Wines',
#   'address': '8627 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.0654907,
#   'long': -123.4402313,
#   'numberofyelpreviews': 7,
#   'yelprating': 5},
#  959: {'names': 'Anderson Valley Pinot Noir Festival',
#   'address': '7000 CA-Hwy 128',
#   'businesstype': 'Festivals',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.17012113,
#   'long': -123.5647669,
#   'numberofyelpreviews': 1,
#   'yelprating': 4},
#  960: {'names': 'Lazy Creek Vineyards',
#   'address': '4741 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.10911,
#   'long': -123.49176,
#   'numberofyelpreviews': 18,
#   'yelprating': 4.5},
#  961: {'names': 'Philo Ridge Vineyards',
#   'address': '14125 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Boonville',
#   'zip': 95415,
#   'lat': 39.0084788,
#   'long': -123.3666112,
#   'numberofyelpreviews': 9,
#   'yelprating': 5},
#  962: {'names': 'Goldeneye Winery',
#   'address': '9200 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.05763245,
#   'long': -123.4327524,
#   'numberofyelpreviews': 135,
#   'yelprating': 4.5},
#  963: {'names': 'Smith Story Wine Cellars',
#   'address': '9000 Ca 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.05949,
#   'long': -123.43456,
#   'numberofyelpreviews': 8,
#   'yelprating': 5},
#  964: {'names': 'Phillips Hill Winery',
#   'address': '5101 Hwy 128',
#   'businesstype': 'Wine Tasting Room',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.102048,
#   'long': -123.491073,
#   'numberofyelpreviews': 24,
#   'yelprating': 4.5},
#  965: {'names': 'Navarro Vineyards & Winery',
#   'address': '5601 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.09609257,
#   'long': -123.4833392,
#   'numberofyelpreviews': 260,
#   'yelprating': 4.5},
#  966: {'names': 'Bink Wines',
#   'address': 'The Madrones',
#   'businesstype': 'Wine Tasting Room',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.059539,
#   'long': -123.434554,
#   'numberofyelpreviews': 16,
#   'yelprating': 4},
#  967: {'names': 'Mazzocco Sonoma',
#   'address': '1400 Lytton Springs Rd',
#   'businesstype': 'Wineries',
#   'city': 'Healdsburg',
#   'zip': 95448,
#   'lat': 38.65516281,
#   'long': -122.8983002,
#   'numberofyelpreviews': 171,
#   'yelprating': 4.5},
#  968: {'names': 'Balo Vineyards',
#   'address': '9001 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.06091,
#   'long': -123.43315,
#   'numberofyelpreviews': 27,
#   'yelprating': 5},
#  969: {'names': 'Handley Cellars',
#   'address': '3151 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.1195,
#   'long': -123.51431,
#   'numberofyelpreviews': 97,
#   'yelprating': 4.5},
#  970: {'names': 'Francis Ford Coppola Winery',
#   'address': '300 Via Archimedes',
#   'businesstype': 'Wineries',
#   'city': 'Geyserville',
#   'zip': 95441,
#   'lat': 38.67840757,
#   'long': -122.8896332,
#   'numberofyelpreviews': 791,
#   'yelprating': 4},
#  971: {'names': 'McFadden Farm',
#   'address': '13275 S Hwy 101',
#   'businesstype': 'Wineries',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.97385679,
#   'long': -123.1157327,
#   'numberofyelpreviews': 26,
#   'yelprating': 5},
#  972: {'names': 'MacCallum House Inn',
#   'address': '45020 Albion St',
#   'businesstype': 'Hotels',
#   'city': 'Mendocino',
#   'zip': 95460,
#   'lat': 39.30573,
#   'long': -123.79925,
#   'numberofyelpreviews': 233,
#   'yelprating': 4},
#  973: {'names': 'Redwood Valley Cellars',
#   'address': '7051 N State St',
#   'businesstype': 'Wineries',
#   'city': 'Redwood Valley',
#   'zip': 95470,
#   'lat': 39.24633,
#   'long': -123.20553,
#   'numberofyelpreviews': 2,
#   'yelprating': 2.5},
#  974: {'names': 'Saracina Vineyards',
#   'address': '11684 S Hwy 101',
#   'businesstype': 'Wine Tours',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.9946,
#   'long': -123.12245,
#   'numberofyelpreviews': 43,
#   'yelprating': 4.5},
#  975: {'names': 'Barra of Mendocino',
#   'address': '7051 N State St',
#   'businesstype': 'Wineries',
#   'city': 'Redwood Valley',
#   'zip': 95470,
#   'lat': 39.24633,
#   'long': -123.20553,
#   'numberofyelpreviews': 36,
#   'yelprating': 4.5},
#  976: {'names': 'Lionstone International',
#   'address': '4791 Dry Creek Rd',
#   'businesstype': 'Wine Tasting Room',
#   'city': 'Healdsburg',
#   'zip': 95448,
#   'lat': 38.673248,
#   'long': -122.934512,
#   'numberofyelpreviews': 26,
#   'yelprating': 4},
#  977: {'names': 'Family Wineries Dry Creek',
#   'address': '300 Via Archimedes',
#   'businesstype': 'Italian',
#   'city': 'Geyserville',
#   'zip': 95441,
#   'lat': 38.68024,
#   'long': -122.88752,
#   'numberofyelpreviews': 659,
#   'yelprating': 4},
#  978: {'names': "Rustic, Francis's Favorites",
#   'address': '4101 Cox-Schrader Rd',
#   'businesstype': 'Wineries',
#   'city': 'Ukiah',
#   'zip': 95482,
#   'lat': 39.09628354,
#   'long': -123.1881134,
#   'numberofyelpreviews': 45,
#   'yelprating': 4.5},
#  979: {'names': 'Rivino Winery',
#   'address': '9000 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.059493,
#   'long': -123.434562,
#   'numberofyelpreviews': 2,
#   'yelprating': 3.5},
#  980: {'names': 'Knez Winery',
#   'address': '4101 Cox-Schrader Rd',
#   'businesstype': 'Wineries',
#   'city': 'Ukiah',
#   'zip': 95482,
#   'lat': 39.09628354,
#   'long': -123.1881134,
#   'numberofyelpreviews': 45,
#   'yelprating': 4.5},
#  981: {'names': 'Rivino Winery',
#   'address': '106 B Matheson St',
#   'businesstype': "Men's Clothing",
#   'city': 'Healdsburg',
#   'zip': 95448,
#   'lat': 38.6102714,
#   'long': -122.8701465,
#   'numberofyelpreviews': 23,
#   'yelprating': 3.5},
#  982: {'names': "Susan's Basement",
#   'address': '13450 S Hwy 101',
#   'businesstype': 'Wineries',
#   'city': 'Hopland',
#   'zip': 95449,
#   'lat': 38.917884,
#   'long': -123.053427,
#   'numberofyelpreviews': 11,
#   'yelprating': 4.5},
#  983: {'names': 'McNab Ridge Winery Tasting Room',
#   'address': '6400 N State St',
#   'businesstype': 'Wineries',
#   'city': 'Calpella',
#   'zip': 95418,
#   'lat': 39.23693176,
#   'long': -123.2049108,
#   'numberofyelpreviews': 40,
#   'yelprating': 5},
#  984: {'names': 'Testa Vineyards',
#   'address': '403 Healdsburg Ave',
#   'businesstype': 'Seafood',
#   'city': 'Healdsburg',
#   'zip': 95448,
#   'lat': 38.6120736,
#   'long': -122.87121,
#   'numberofyelpreviews': 1169,
#   'yelprating': 4},
#  985: {'names': "Willi's Seafood & Raw Bar",
#   'address': '9200 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.05763245,
#   'long': -123.4327524,
#   'numberofyelpreviews': 135,
#   'yelprating': 4.5},
#  986: {'names': 'Goldeneye Winery',
#   'address': '8501 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.07118,
#   'long': -123.44043,
#   'numberofyelpreviews': 61,
#   'yelprating': 3.5},
#  987: {'names': 'Scharffenberger Cellars',
#   'address': '501 Parducci Rd',
#   'businesstype': 'Wineries',
#   'city': 'Ukiah',
#   'zip': 95482,
#   'lat': 39.199731,
#   'long': -123.212281,
#   'numberofyelpreviews': 74,
#   'yelprating': 4.5},
#  988: {'names': 'Parducci Wine Cellars',
#   'address': '550 Nelson Ranch Rd',
#   'businesstype': 'Wineries',
#   'city': 'Ukiah',
#   'zip': 95482,
#   'lat': 39.050344,
#   'long': -123.164259,
#   'numberofyelpreviews': 33,
#   'yelprating': 4.5},
#  989: {'names': 'Nelson Family Vineyards',
#   'address': '5601 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Philo',
#   'zip': 95466,
#   'lat': 39.09609257,
#   'long': -123.4833392,
#   'numberofyelpreviews': 260,
#   'yelprating': 4.5},
#  990: {'names': 'Navarro Vineyards & Winery',
#   'address': '3001 S State St',
#   'businesstype': 'Wineries',
#   'city': 'Ukiah',
#   'zip': 95482,
#   'lat': 39.111389,
#   'long': -123.195895,
#   'numberofyelpreviews': 24,
#   'yelprating': 5},
#  991: {'names': 'Simaine Cellars',
#   'address': '1123 S Cloverdale Blvd',
#   'businesstype': 'Wineries',
#   'city': 'Cloverdale',
#   'zip': 95425,
#   'lat': 38.9004919,
#   'long': -123.2210146,
#   'numberofyelpreviews': 2,
#   'yelprating': 2.5},
#  992: {'names': 'Le Vin Estate Winery',
#   'address': '336 Healdsburg Ave',
#   'businesstype': 'Italian',
#   'city': 'Healdsburg',
#   'zip': 95448,
#   'lat': 38.61175,
#   'long': -122.87058,
#   'numberofyelpreviews': 312,
#   'yelprating': 4},
#  993: {'names': 'Baci Cafe and Wine Bar',
#   'address': '19750 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Yorkville',
#   'zip': 95494,
#   'lat': 38.9447596,
#   'long': -123.3220087,
#   'numberofyelpreviews': 20,
#   'yelprating': 4.5},
#  994: {'names': 'Meyer Family Cellars',
#   'address': '19750 Hwy 128',
#   'businesstype': 'Wineries',
#   'city': 'Yorkville',
#   'zip': 95494,
#   'lat': 38.9447596,
#   'long': -123.3220087,
#   'numberofyelpreviews': 20,
#   'yelprating': 4.5},
#  995: {'names': 'Meyer Family Cellars',
#   'address': '9545 E Mariposa Way',
#   'businesstype': 'Pick Your Own Farms',
#   'city': 'Le Grand',
#   'zip': 95333,
#   'lat': 37.25058565,
#   'long': -120.3167527,
#   'numberofyelpreviews': 1,
#   'yelprating': 5},
#  996: {'names': 'Le Grand Berry Farms',
#   'address': '60090 Highway 395',
#   'businesstype': 'Wineries',
#   'city': 'Davis Creek',
#   'zip': 96108,
#   'lat': 41.991505,
#   'long': -120.298453,
#   'numberofyelpreviews': 4,
#   'yelprating': 4.5},
#  997: {'names': "Stringer's Orchard Winery & Distillery",
#   'address': '7624 N Co Rd 114',
#   'businesstype': 'Wineries',
#   'city': 'Tulelake',
#   'zip': 96134,
#   'lat': 41.9579211,
#   'long': -121.3430836,
#   'numberofyelpreviews': 2,
#   'yelprating': 5},
#  998: {'names': 'Bloody Point Vineyard',
#   'address': '8940 Carmel Valley Rd',
#   'businesstype': 'Wineries',
#   'city': 'Carmel',
#   'zip': 93923,
#   'lat': 36.528461,
#   'long': -121.819702,
#   'numberofyelpreviews': 242,
#   'yelprating': 4},
#  999: {'names': 'Folktale Winery',
#   'address': '700 Cannery Row',
#   'businesstype': 'Venues & Event Spaces',
#   'city': 'Monterey',
#   'zip': 93940,
#   'lat': 36.61628481,
#   'long': -121.9003369,
#   'numberofyelpreviews': 450,
#   'yelprating': 4},
#  1000: {'names': 'A Taste of Monterey - Wine Market & Bistro',
#   'address': '1 Pilot Rd',
#   'businesstype': 'Wineries',
#   'city': 'Carmel Valley',
#   'zip': 93924,
#   'lat': 36.4803093,
#   'long': -121.7340546,
#   'numberofyelpreviews': 83,
#   'yelprating': 4},
#  ...}
